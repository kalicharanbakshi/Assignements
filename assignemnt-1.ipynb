# %%
file_location = "/FileStore/tables/yellow_tripdata_2018_01.parquet"
df =spark.read.parquet(file_location,header=True,inferSchema=True)
df.show()
# Out:
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|congestion_surcharge|airport_fee|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# |       1| 2018-01-01 00:21:05|  2018-01-01 00:24:23|              1|          0.5|         1|                 N|          41|          24|           2|        4.5|  0.5|    0.5|       0.0|         0.0|                  0.3|         5.8|                null|       null|
# |       1| 2018-01-01 00:44:55|  2018-01-01 01:03:05|              1|          2.7|         1|                 N|         239|         140|           2|       14.0|  0.5|    0.5|       0.0|         0.0|                  0.3|        15.3|                null|       null|
# |       1| 2018-01-01 00:08:26|  2018-01-01 00:14:21|              2|          0.8|         1|                 N|         262|         141|           1|        6.0|  0.5|    0.5|       1.0|         0.0|                  0.3|         8.3|                null|       null|
# |       1| 2018-01-01 00:20:22|  2018-01-01 00:52:51|              1|         10.2|         1|                 N|         140|         257|           2|       33.5|  0.5|    0.5|       0.0|         0.0|                  0.3|        34.8|                null|       null|
# |       1| 2018-01-01 00:09:18|  2018-01-01 00:27:06|              2|          2.5|         1|                 N|         246|         239|           1|       12.5|  0.5|    0.5|      2.75|         0.0|                  0.3|       16.55|                null|       null|
# |       1| 2018-01-01 00:29:29|  2018-01-01 00:32:48|              3|          0.5|         1|                 N|         143|         143|           2|        4.5|  0.5|    0.5|       0.0|         0.0|                  0.3|         5.8|                null|       null|
# |       1| 2018-01-01 00:38:08|  2018-01-01 00:48:24|              2|          1.7|         1|                 N|          50|         239|           1|        9.0|  0.5|    0.5|      2.05|         0.0|                  0.3|       12.35|                null|       null|
# |       1| 2018-01-01 00:49:29|  2018-01-01 00:51:53|              1|          0.7|         1|                 N|         239|         238|           1|        4.0|  0.5|    0.5|       1.0|         0.0|                  0.3|         6.3|                null|       null|
# |       1| 2018-01-01 00:56:38|  2018-01-01 01:01:05|              1|          1.0|         1|                 N|         238|          24|           1|        5.5|  0.5|    0.5|       1.7|         0.0|                  0.3|         8.5|                null|       null|
# |       1| 2018-01-01 00:17:04|  2018-01-01 00:22:24|              1|          0.7|         1|                 N|         170|         170|           2|        5.5|  0.5|    0.5|       0.0|         0.0|                  0.3|         6.8|                null|       null|
# |       1| 2018-01-01 00:41:03|  2018-01-01 00:46:49|              1|          0.6|         1|                 N|         162|         229|           1|        5.5|  0.5|    0.5|      1.35|         0.0|                  0.3|        8.15|                null|       null|
# |       1| 2018-01-01 00:52:54|  2018-01-01 01:17:33|              1|          3.5|         1|                 N|         141|         113|           2|       16.5|  0.5|    0.5|       0.0|         0.0|                  0.3|        17.8|                null|       null|
# |       2| 2018-01-01 00:17:54|  2018-01-01 00:22:05|              1|         1.04|         1|                 N|         137|         224|           2|        5.5|  0.5|    0.5|       0.0|         0.0|                  0.3|         6.8|                null|       null|
# |       2| 2018-01-01 00:24:47|  2018-01-01 00:34:20|              1|         1.22|         1|                 N|         224|          79|           2|        7.5|  0.5|    0.5|       0.0|         0.0|                  0.3|         8.8|                null|       null|
# |       2| 2018-01-01 00:37:57|  2018-01-01 00:53:43|              1|         1.92|         1|                 N|         234|         100|           2|       10.0|  0.5|    0.5|       0.0|         0.0|                  0.3|        11.3|                null|       null|
# |       1| 2018-01-01 00:35:53|  2018-01-01 00:52:59|              1|          5.7|         1|                 N|          13|         189|           1|       19.0|  0.5|    0.5|      4.05|         0.0|                  0.3|       24.35|                null|       null|
# |       2| 2018-01-01 00:30:47|  2018-01-01 01:13:20|              1|         3.74|         1|                 N|          48|         236|           1|       25.5|  0.5|    0.5|       6.7|         0.0|                  0.3|        33.5|                null|       null|
# |       1| 2018-01-01 00:21:45|  2018-01-01 00:25:58|              2|          0.6|         1|                 N|         163|         162|           1|        4.5|  0.5|    0.5|       1.7|         0.0|                  0.3|         7.5|                null|       null|
# |       1| 2018-01-01 00:31:11|  2018-01-01 01:07:56|              1|         10.9|         1|                 N|         229|          61|           2|       35.0|  0.5|    0.5|       0.0|         0.0|                  0.3|        36.3|                null|       null|
# |       2| 2018-01-01 00:15:42|  2018-01-01 00:21:38|              5|         1.22|         1|                 N|         236|          75|           2|        6.0|  0.5|    0.5|       0.0|         0.0|                  0.3|         7.3|                null|       null|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# only showing top 20 rows

# %%
df.schema
# Out:
# Out[2]: StructType(List(StructField(VendorID,LongType,true),StructField(tpep_pickup_datetime,TimestampType,true),StructField(tpep_dropoff_datetime,TimestampType,true),StructField(passenger_count,LongType,true),StructField(trip_distance,DoubleType,true),StructField(RatecodeID,LongType,true),StructField(store_and_fwd_flag,StringType,true),StructField(PULocationID,LongType,true),StructField(DOLocationID,LongType,true),StructField(payment_type,LongType,true),StructField(fare_amount,DoubleType,true),StructField(extra,DoubleType,true),StructField(mta_tax,DoubleType,true),StructField(tip_amount,DoubleType,true),StructField(tolls_amount,DoubleType,true),StructField(improvement_surcharge,DoubleType,true),StructField(total_amount,DoubleType,true),StructField(congestion_surcharge,DoubleType,true),StructField(airport_fee,DoubleType,true)))

# %% [markdown]
# Query 1. - Add a column named as "Revenue" into dataframe which is the sum of the below columns 'Fare_amount','Extra','MTA_tax','Improvement_surcharge','Tip_amount','Tolls_amount','Total_amount'

# %%
import pyspark.sql.functions as F
df_new=df.withColumn("revenue",(F.col('Fare_amount')+F.col('Extra')+F.col('MTA_tax')+F.col('Improvement_surcharge')+F.col('Tip_amount')+F.col('Tolls_amount')+F.col('Total_amount')))

# %%
df_new.head()
# Out:
# Out[4]: Row(VendorID=1, tpep_pickup_datetime=datetime.datetime(2018, 1, 1, 0, 21, 5), tpep_dropoff_datetime=datetime.datetime(2018, 1, 1, 0, 24, 23), passenger_count=1, trip_distance=0.5, RatecodeID=1, store_and_fwd_flag='N', PULocationID=41, DOLocationID=24, payment_type=2, fare_amount=4.5, extra=0.5, mta_tax=0.5, tip_amount=0.0, tolls_amount=0.0, improvement_surcharge=0.3, total_amount=5.8, congestion_surcharge=None, airport_fee=None, revenue=11.6)

# %% [markdown]
# Query 2. - Increasing count of total passengers in New York City by area

# %%
df.groupBy("PULocationID").agg(F.sum("passenger_count").alias("total_number"))
            .sort(F.col("total_number")).show()
# Out:
# +------------+------------+
# |PULocationID|total_number|
# +------------+------------+
# |          44|           1|
# |         204|           1|
# |         184|           2|
# |         187|           2|
# |         176|           3|
# |          46|           3|
# |           5|           3|
# |          58|           4|
# |           2|           4|
# |          30|           4|
# |         199|           4|
# |         245|           5|
# |         221|           6|
# |         214|           6|
# |         105|           8|
# |         156|           8|
# |          84|           8|
# |         109|           8|
# |         251|           9|
# |         115|          12|
# +------------+------------+
# only showing top 20 rows

# %% [markdown]
# Query 3. - Realtime Average fare/total earning amount earned by 2 vendors

# %%
display(df_new.groupBy("VendorID").agg(F.sum("revenue")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>VendorID</th><th>sum(revenue)</th></tr></thead><tbody><tr><td>1</td><td>1.1636389409691693E8</td></tr><tr><td>2</td><td>1.550309307433578E8</td></tr></tbody></table></div>

# %% [markdown]
# Query 4. - Moving Count of payments made by each payment mode

# %%
display(df_new.groupBy("payment_type").count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>payment_type</th><th>count</th></tr></thead><tbody><tr><td>1</td><td>6106416</td></tr><tr><td>3</td><td>43204</td></tr><tr><td>2</td><td>2599215</td></tr><tr><td>4</td><td>11852</td></tr></tbody></table></div>

# %% [markdown]
# Query 5. - Highest two gaining vendor's on a particular date with no of passenger and total distance by cab

# %%
df_new=df_new.withColumn("date",F.to_date("tpep_pickup_datetime"))

# %%
temp_df=df_new.groupBy("VendorID","date")
             .agg(F.sum("revenue").alias("total_revenue"),
             F.sum("passenger_count").alias("total_number"),
             F.sum("trip_distance").alias("total_distance")).
             sort(F.desc("total_revenue"))

# %%
date="2018-1-25"
display(temp_df.filter(F.col("date")==date)
        .sort(F.desc("total_revenue"))
        .limit(2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>VendorID</th><th>date</th><th>total_revenue</th><th>total_number</th><th>total_distance</th></tr></thead><tbody><tr><td>2</td><td>2018-01-25</td><td>5966751.749995339</td><td>351475</td><td>518394.0400000009</td></tr><tr><td>1</td><td>2018-01-25</td><td>4585064.500002595</td><td>172376</td><td>383772.20000000275</td></tr></tbody></table></div>

# %% [markdown]
# Query 6. - Most no of passenger between a route of two location.

# %%
display(df_new.groupBy("PULocationID","DOLocationID").agg(F.sum("passenger_count").alias("total_count"))
                                                          .sort(F.desc("total_count"))
                                                          .limit(1))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PULocationID</th><th>DOLocationID</th><th>total_count</th></tr></thead><tbody><tr><td>264</td><td>264</td><td>186705</td></tr></tbody></table></div>

# %% [markdown]
# Query 7. - Get top pickup locations with most passengers in last 5/10 seconds

# %%
date="2018-01-01 00:21:05"
display(df.filter((F.col("tpep_pickup_datetime")<(F.col("tpep_pickup_datetime")+F.expr("INTERVAL 10 SECONDS")))  & (F.col("tpep_pickup_datetime")>(F.col("tpep_pickup_datetime")-F.expr("INTERVAL 10 SECONDS"))) ).groupby(F.col("PULocationID")).count().sort(F.desc("count")).limit(1))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PULocationID</th><th>count</th></tr></thead><tbody><tr><td>237</td><td>361012</td></tr></tbody></table></div>
